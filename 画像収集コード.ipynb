# %%
# from icrawler.builtin import GoogleImageCrawler
# 欲しい画像を○○○枚取得
# crawler = GoogleImageCrawler(storage={"root_dir": "〇〇〇"})
# crawler.crawl(keyword="〇〇", max_num=○○○)
from icrawler.builtin import BingImageCrawler

# 〇〇の画像を○○○枚取得
crawler = BingImageCrawler(storage={"root_dir": "soccer"}) # フォルダー名
crawler.crawl(keyword="サッカーボール", max_num=100) # ほしい画像：枚数
# Out:
# 2020-12-28 00:17:00,973 - INFO - icrawler.crawler - start crawling...
# 2020-12-28 00:17:00,974 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-12-28 00:17:00,975 - INFO - feeder - thread feeder-001 exit
# 2020-12-28 00:17:00,977 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-12-28 00:17:00,978 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-12-28 00:17:01,007 - ERROR - parser - Exception caught when fetching page https://www.bing.com/images/async?q=サッカーボール&first=0, error: ('Connection aborted.', ConnectionResetError(10054, '既存の接続はリモート ホストに強制的に切断されました。', None, 10054, None)), remaining retry times: 2
# 2020-12-28 00:17:01,353 - INFO - parser - parsing result page https://www.bing.com/images/async?q=サッカーボール&first=0
# 2020-12-28 00:17:01,545 - INFO - downloader - image #1	https://blog-imgs-88.fc2.com/s/u/p/supergensan/20160131142515b98.jpg
# ...
